# %%
pwd
# Out:
# '/Users/apple/Desktop/ShoestringHackathon2020'

# %%
import os

# %%
TRAIN_DIR = "/Users/apple/Desktop/ShoestringHackathon2020/TrainingData/train/images/"
VAL_DIR = "/Users/apple/Desktop/ShoestringHackathon2020/TrainingData/validation/images/"

# %%
cd "/Users/apple/Desktop/ShoestringHackathon2020/TrainingData/train/images/"
# Out:
# /Users/apple/Desktop/ShoestringHackathon2020/TrainingData/train/images

# %%
# Rename training images
train_names = os.listdir(TRAIN_DIR)
for i,name in enumerate(train_names):
    new_name = 'img_'+str(i+1)+'.jpg'
    os.rename(name,new_name)

# %%
cd "/Users/apple/Desktop/ShoestringHackathon2020/TrainingData/validation/images/"
# Out:
# /Users/apple/Desktop/ShoestringHackathon2020/TrainingData/validation/images

# %%
pwd
# Out:
# '/Users/apple/Desktop/ShoestringHackathon2020/TrainingData/validation/images'

# %%
# Rename training images
test_names = os.listdir(VAL_DIR)
for i,name in enumerate(test_names):
    new_name = 'img_'+str(i+1+640)+'.jpg'
    os.rename(name,new_name)

# %%
test_names
# Out:
# ['img_329.jpg',
#  'img_473.jpg',
#  'img_315.jpg',
#  'img_301.jpg',
#  'img_467.jpg',
#  'img_10.jpg',
#  'img_498.jpg',
#  'img_38.jpg',
#  'img_117.jpg',
#  'img_103.jpg',
#  'img_249.jpg',
#  'img_507.jpg',
#  'img_1.jpg',
#  'img_261.jpg',
#  'img_275.jpg',
#  'img_513.jpg',
#  'img_274.jpg',
#  'img_512.jpg',
#  'img_506.jpg',
#  'img_260.jpg',
#  'img_248.jpg',
#  'img_102.jpg',
#  'img_116.jpg',
#  'img_39.jpg',
#  'img_499.jpg',
#  'img_11.jpg',
#  'img_300.jpg',
#  'img_466.jpg',
#  'img_472.jpg',
#  'img_314.jpg',
#  'img_328.jpg',
#  'img_458.jpg',
#  'img_464.jpg',
#  'img_302.jpg',
#  'img_316.jpg',
#  'img_470.jpg',
#  'img_13.jpg',
#  'img_128.jpg',
#  'img_100.jpg',
#  'img_114.jpg',
#  'img_538.jpg',
#  'img_510.jpg',
#  'img_276.jpg',
#  'img_2.jpg',
#  'img_262.jpg',
#  'img_504.jpg',
#  'img_289.jpg',
#  'img_288.jpg',
#  'img_263.jpg',
#  'img_3.jpg',
#  'img_505.jpg',
#  'img_511.jpg',
#  'img_277.jpg',
#  'img_539.jpg',
#  'img_115.jpg',
#  'img_101.jpg',
# ...
